# %%
print ("Hola Mundo!")
# Out:
# Hola Mundo!

# %%
print ("Mi nombre es Brandon Montoya. Esta es la materia")
# Out:
# Mi nombre es Brandon Montoya. Esta es la materia

# %%
mensaje = "Hola Mundo"
print (mensaje)
# Out:
# Hola Mundo

# %%
mi_nombre = "Brandon"
print (mi_nombre)
# Out:
# Brandon

# %%
mensaje = "Hola. Bienvenido a Python!"
print (mensaje)
# Out:
# Hola. Bienvenido a Python!

# %%
"Jose"
"Mario"
"10"
"enero"
"Título de la novela: Cien años de Soledad"

'Autor: Gabriel García Márquez'
# Out:
# 'Autor: Gabriel García Márquez'

# %%
nombre = "brandon"

print (nombre.title())
# Out:
# Brandon

# %%
nombre = "brandon"
print (nombre.upper())   
print (nombre.lower())
# Out:
# BRANDON
# brandon

# %%
primer_nombre = "brandon"
apellidos = "montoya naranjo"
nombre_completo = primer_nombre + " " + apellidos
print(nombre_completo)
# Out:
# brandon montoya naranjo

# %%
print ("Python")
print ("\tPython")
# Out:
# Python
# 	Python

# %%
print ("Languajes:\nPython\nC\nJavaScript")
# Out:
# Languajes:
# Python
# C
# JavaScript

# %%
print ("Languajes:\n\tPython\n\tC\n\tJavaScript")
# Out:
# Languajes:
# 	Python
# 	C
# 	JavaScript

# %%
lenguaje_1 = "python   "
lenguaje_2 = "     python"

print ("Sin eliminar los espacios")
print ()
print (lenguaje_1)
print (lenguaje_2)
print ()
print ("Eliminando los espacios")
print ()
print (lenguaje_1.rstrip())
print (lenguaje_2.lstrip())
# Out:
# Sin eliminar los espacios
#
# python
#      python
#
# Eliminando los espacios
#
# python
# python

# %% [markdown]
# **Números**

# %%
print (7 + 3)
print (8 - 9)
print (5 * 3)
print (4 / 2)
# Out:
# 10
# -1
# 15
# 2.0

# %%
print (5 ** 5)
print (2 ** 3)
print (1 ** 4)
# Out:
# 3125
# 8
# 1

# %%
print (2 + 3*2)
print ( (2 + 3) * 2)
# Out:
# 8
# 10

# %% [markdown]
# **Números de tipo float**

# %%
print (0.4 + 0.6)
print (0.3 + 0.2)
print (2 * 0.6)
print (2 * 0.9)
# Out:
# 1.0
# 0.5
# 1.2
# 1.8

# %%
print (0.5 + 0.1)
print (3 * 0.2)
# Out:
# 0.6
# 0.6000000000000001

# %%
edad = 18
print ("La edad de Brandon es de " + str(edad) + " años")
# Out:
# La edad de Brandon es de 18 años
