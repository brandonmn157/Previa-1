# %% [markdown]
# **TRABAJANDO CON LISTAS**

# %% [markdown]
# **Iterando sobre una lista**

# %%
magos = ['jhon', 'brandon', 'jack']

for un_mago in magos:  
  print (un_mago)
# Out:
# jhon
# brandon
# jack

# %%
i = 1
for un_mago in magos:
  print (un_mago + " eres un mago")
  print ("Estas en la lista en el número: " + str(i))
  print ()
  i = i + 1
# Out:
# jhon eres un mago
# Estas en la lista en el número: 1
#
# brandon eres un mago
# Estas en la lista en el número: 2
#
# jack eres un mago
# Estas en la lista en el número: 3

# %% [markdown]
# **Creando una lista numérica**

# %% [markdown]
# **Función range()**

# %%
for valor in range(1, 6):
  print (valor)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Construyendo LISTAS usando la función range()**

# %%
numeros = list ( range(1, 10) )
print (numeros)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# **Variante de la función range(). Incremento**

# %%
impares = list ( range(1, 10, 2) ) 
print (impares)
# Out:
# [1, 3, 5, 7, 9]

# %%
lista_cuadrados = []    
for valor in range (1, 10):
  cuadrado = valor ** 2               
  lista_cuadrados.append( cuadrado )  

print (lista_cuadrados)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
lista_cuadrados = []
for valor in range (1, 10):
  lista_cuadrados.append( valor ** 2)

print (lista_cuadrados)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# **Listas por comprensión**

# %%
lista_cuadrados = [valor**2 for valor in range(1,12)]
print (lista_cuadrados)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121]

# %% [markdown]
# **Estadistica simple con listas de números**

# %%
digitos = [0, 2, 4, 6, 8, 10, 12, 14]

print (min(digitos))    
print (max(digitos))   
print (sum(digitos))
# Out:
# 0
# 14
# 56

# %% [markdown]
# **Haciendo cortes a una lista**

# %%
jugadores = ['pepe', 'mario', 'jack', 'jose', 'alvaro', 'santiago']
print (jugadores[0:3])
# Out:
# ['pepe', 'mario', 'jack']

# %% [markdown]
# **Omitiendo el primer elemento del corte a una lista**

# %%
print (jugadores[:4])
# Out:
# ['pepe', 'mario', 'jack', 'jose']

# %% [markdown]
# **Omitiendo el segundo elemento de una lista**

# %%
print (jugadores[4:])
# Out:
# ['alvaro', 'santiago']

# %% [markdown]
# **Omitiendo los dos índices**

# %%
print (jugadores[:])
# Out:
# ['pepe', 'mario', 'jack', 'jose', 'alvaro', 'santiago']

# %% [markdown]
# **Utilizando los últimos elementos de la lista**

# %%
print (jugadores[-1:])
# Out:
# ['santiago']

# %%
print (jugadores[-2:])
# Out:
# ['alvaro', 'santiago']

# %%
print (jugadores[-3:])
# Out:
# ['jose', 'alvaro', 'santiago']

# %% [markdown]
# **Iterando sobre los elementos del corte de una lista**

# %%
jugadores = ['pepe', 'mario', 'jack', 'jose', 'alvaro', 'santiago']
for valor in jugadores[0:3]:
  print (valor)
# Out:
# pepe
# mario
# jack

# %% [markdown]
# **Copiando los elementos de una lista**

# %%
mis_peliculas = ['bond', 'matrix', 'avengers', 'padrino']
peliculas_amigo = mis_peliculas[:]

print (mis_peliculas)
print ()
print (peliculas_amigo)
# Out:
# ['bond', 'matrix', 'avengers', 'padrino']
#
# ['bond', 'matrix', 'avengers', 'padrino']

# %% [markdown]
# **TUPLAS**

# %% [markdown]
# **Definiendo una tupla**

# %%
dimensiones = (600, 20)

print (dimensiones[0])
print (dimensiones[1])
# Out:
# 600
# 20

# %% [markdown]
# **Veamos qué sucede si intentamos cambiar uno de los elementos de la tupla.**

# %%
dimensiones[0] = 620
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-15f3bdd89a55> in <module>()
# ----> 1 dimensiones[0] = 620
#       2
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Recorrer todos los valores en una tupla**

# %%
# Se recorre la tupla

dimensiones = (600, 20)

for una_dimension in dimensiones:
  print (una_dimension)
# Out:
# 600
# 20

# %% [markdown]
# **Escribir sobre una tupla**

# %%
dimensiones = (600, 20)

print ("Dimensiones Originales:")
for dimension in dimensiones:
  print (dimension)

dimensiones = (300, 100)

print ("\nDimensiones Modificadas:")
for dimension in dimensiones:
  print (dimension)
# Out:
# Dimensiones Originales:
# 600
# 20
#
# Dimensiones Modificadas:
# 300
# 100

# %% [markdown]
# ## Final del módulo: trabajando con Listas
